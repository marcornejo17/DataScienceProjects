# %%
# %matplotlib inline

try:
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    import matplotlib as mpl
    import matplotlib.pyplot as plt
    import seaborn as sns
except ModuleNotFoundError as err:
    print("Python says:", err, "... possibly because it isn't installed on your system?")
except:
    print("Some other error occurred when importing.")
else:
    print("Imports successful!")
    sns.set()
# Out:
# Imports successful!

# %%
# %matplotlib inline
sns.set_style('ticks')

import warnings
warnings.filterwarnings('ignore')

# %%
survey_data = pd.read_csv('jovcov.csv')
survey_data.head()
# Out:
#    Unnamed: 0 edad   genero  roomies -25  roomies 26-59  roomies +60  \
# 0         NaN    18   Mujer            2              2          NaN
# 1         NaN    20   Mujer            3              3          0.0
# 2         NaN    20  Hombre            2              2          0.0
# 3         NaN    20   Mujer            1              3          0.0
# 4         NaN    20  Hombre            2              2          0.0
#
#                      con quien vive     estado civil  escalaridad jefa de fam  \
# 0         Madre, Hermanas, hermanos  Soltera/soltero                       73
# 1         Madre, Hermanas, hermanos  Soltera/soltero                       31
# 2  Madre, Padre, Hermanas, hermanos  Soltera/soltero                      101
# 3  Madre, Padre, Hermanas, hermanos  Soltera/soltero                       59
# 4  Madre, Padre, Hermanas, hermanos  Soltera/soltero                      101
#
#   baños  ...                                     identificación  \
# ...

# %%
sns.displot(data=survey_data, x="días sociales", col="personas en riesgo", kde=True)

# %%
sns.displot(data=survey_data, x="suma día que se sale", col="personas en riesgo", kde=True)

# %%
sns.catplot(data=survey_data, kind="bar", x="personas en riesgo", y="suma día que se sale", hue="genero")

# %%
sns.catplot(data=survey_data, kind="bar", x="personas en riesgo", y="días sociales", hue="genero")

# %%
sns.catplot(data=survey_data, kind="bar", x="personas contagiadas en casa", y="suma día que se sale", hue="genero")

# %%
sns.catplot(data=survey_data, kind="bar", x="personas en riesgo", y="suma día que se sale", hue="estado civil")

# %%
sns.catplot(data=survey_data, kind="bar", x="personas contagiadas en casa", y="días sociales", hue="genero")

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="días sociales",hue="identificación",
    multiple="dodge",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 5, 10, 15, 18])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="días sociales",hue="afirmaciones covid ",
    multiple="dodge",
    palette="light:k_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 5, 10, 15, 18])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="días sociales",hue="viñeta juan y beto",
    multiple="dodge",
    palette="light:g_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 5, 10, 15, 18])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="días sociales",hue="viñeta maria lucia ",
    multiple="dodge",
    palette="light:r_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 5, 10, 15, 18])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="personas en riesgo",hue="viñeta juan y beto",
    multiple="dodge",
    palette="light:b_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 1, 2, 3, 4])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="personas en riesgo",hue="viñeta maria lucia ",
    multiple="dodge",
    palette="light:y_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 1, 2, 3, 4])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="días sociales",hue="noticias covid ",
    multiple="dodge",
    palette="light:b_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 5, 10, 15, 20])

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(data=survey_data,x="personas en riesgo",hue="noticias covid ",
    multiple="dodge",
    palette="light:c_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False)

ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([ 0, 1, 2, 3, 4])
